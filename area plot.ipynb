# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
area1=[2,6,8,9,2]
area2=[4,8,6,7,1]
area3=[1,3,6,5,9]
l=["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,colors=["r","g","b"])


plt.title("Area-plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc=2)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
